# %%
import sqlite3 as sq

# %% [markdown]
# # Create the Database

# %%
database = sq.connect("employee.db")
print("Database Successfuly created!")
# Out:
# Database Successfuly created!

# %% [markdown]
# # Perform the Queries

# %%
CREATE TABLE table_name(
    Name char(100),
    Age int
);

# database.execute()

# %% [markdown]
# # Create a table

# %%
database.execute("CREATE TABLE table_name(Name char(100),Age int);")

print("Table created")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 database.execute("CREATE TABLE table_name(Name char(100),Age int);")
#       3 print("Table created")
#
# OperationalError: table table_name already exists

# %%
cur = database.cursor()

# %%
cur.execute("SELECT * FROM table_name;")
cur.fetchall()
# Out:
# []

# %%
database.execute('''INSERT INTO table_name 
VALUES('Harsh',25);

''')

database.execute("INSERT INTO table_name VALUES('Naiteek',35);")
database.execute("INSERT INTO table_name VALUES('Mahek',55);")

print("Data has been inserted")
# Out:
# Data has been inserted

# %%
data = database.execute("SELECT * FROM table_name;")

# %%
for i in data:
  print(i)
# Out:
# ('Tony', 25)
# ('Loki', 35)
# ('Steve', 55)
# ('Harsh', 25)
# ('Naiteek', 35)
# ('Mahek', 55)

# %%
print(data)

# %%
1. Numpy (Scipy) 2-3    
2. Pandas 2
3. Matplotlib (Seaborn) 2

Regex - Data Cleaning

6 days - 6 Projects
Stats - 
ML - 10 models (10 Project)
DL
